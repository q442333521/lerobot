# %% [markdown]
# # 安装检查
#
# 这个 Notebook 检查所有必需的依赖是否正确安装。
#
# 运行这个 Notebook 来验证您的环境是否已正确配置，可以开始使用 MuJoCo + SmolVLA。

# %% [markdown]
# ---
# ## 📦 步骤 1: 定义检查函数

# %%
def check_module(module_name, package_name=None, import_test=None):
    """检查模块是否安装"""
    if package_name is None:
        package_name = module_name

    try:
        if import_test:
            exec(import_test)
        else:
            __import__(module_name)
        print(f"✓ {package_name:20s} - 已安装")
        return True
    except ImportError as e:
        print(f"✗ {package_name:20s} - 未安装")
        print(f"  错误: {e}")
        return False

# %% [markdown]
# ---
# ## 🔍 步骤 2: 检查基础依赖

# %%
print("=" * 70)
print("🔍 LeRobot MuJoCo 环境安装检查")
print("=" * 70)
print()

all_ok = True

# 基础依赖
print("📦 基础依赖:")
all_ok &= check_module("numpy", "NumPy")
all_ok &= check_module("torch", "PyTorch")
all_ok &= check_module("PIL", "Pillow")
print()

# %% [markdown]
# ---
# ## 🤖 步骤 3: 检查 LeRobot

# %%
print("🤖 LeRobot:")
all_ok &= check_module("lerobot", "LeRobot")
all_ok &= check_module("lerobot.datasets", "LeRobot Datasets")
all_ok &= check_module("lerobot.rl", "LeRobot RL")
print()

# %% [markdown]
# ---
# ## 🎮 步骤 4: 检查仿真环境

# %%
print("🎮 仿真环境:")
all_ok &= check_module("mujoco", "MuJoCo")
all_ok &= check_module("gymnasium", "Gymnasium")
gym_hil_ok = check_module("gym_hil", "gym_hil")
all_ok &= gym_hil_ok
print()

# %% [markdown]
# ---
# ## 🧠 步骤 5: 检查 SmolVLA

# %%
print("🧠 SmolVLA:")
smolvla_ok = check_module(
    "lerobot.policies.smolvla",
    "SmolVLA Policy",
    "from lerobot.policies.smolvla import SmolVLAPolicy"
)
all_ok &= smolvla_ok
print()

# %% [markdown]
# ---
# ## 💻 步骤 6: 检查 GPU

# %%
print("💻 硬件:")
import torch

if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"✓ CUDA GPU           - {gpu_name}")
    print(f"  显存: {gpu_memory:.1f} GB")
else:
    print("✗ CUDA GPU           - 未检测到")
    print("  警告: 没有 GPU，训练会非常慢")
print()

# %% [markdown]
# ---
# ## 🔧 步骤 7: 检查可选依赖

# %%
print("🔧 可选依赖:")
check_module("wandb", "Weights & Biases")
check_module("cv2", "OpenCV", "import cv2")
print()

# %% [markdown]
# ---
# ## ✅ 总结

# %%
print("=" * 70)
if all_ok:
    print("✅ 所有必需依赖都已安装！")
    print("\n🎉 您可以开始使用 MuJoCo 环境了")
    print("\n下一步:")
    print("  1. 配置 mujoco_so101_config.json")
    print("  2. 运行 01_collect_mujoco_data.ipynb")
else:
    print("❌ 部分依赖缺失")
    print("\n安装缺失的依赖:")

    if not gym_hil_ok:
        print("\n  gym_hil:")
        print("    pip install -e '.[hilserl]'")

    if not smolvla_ok:
        print("\n  SmolVLA:")
        print("    pip install -e '.[smolvla]'")

    print("\n或安装所有依赖:")
    print("  pip install -e '.[hilserl,smolvla]'")

print("=" * 70)

# %% [markdown]
# ---
#
# ## 📝 安装说明
#
# 如果某些依赖缺失，请在终端运行以下命令：
#
# ```bash
# # 返回到 lerobot 根目录
# cd /path/to/lerobot
#
# # 安装 MuJoCo 和 gym_hil
# pip install -e ".[hilserl]"
#
# # 安装 SmolVLA
# pip install -e ".[smolvla]"
#
# # 或一次性安装所有
# pip install -e ".[hilserl,smolvla]"
# ```
#
# 安装完成后，重新运行此 Notebook 验证。
